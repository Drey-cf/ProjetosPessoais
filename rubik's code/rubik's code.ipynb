# %%
# Esse código foi desensolvido para eu decorar alguns padrões do Cubo Mágico de forma mais didática. Ele contêm os seguintes padrões (estão em francês):  
# Ec  (sub 4)  les I: I (sub 5)   les Poissons: Po (sub 4)   les H:H  les petit ls:l

from IPython.display import display, Image
import time
from numpy import random

for i in range(5):
    j = random.choice(range(1, 9))
    try:
        display(Image(filename = f'l{j}.png'))
    except:
        continue
    time.sleep(10)
    
print('FIM')
# Out:
# FIM
